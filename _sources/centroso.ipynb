# %% [markdown]
# # **Centros Oncológicos en Colombia**

# %%
prueba = pd.read_csv("C:\\Users\\kamac\\Downloads\\Prestadores_de_Servicios_de_Salud_del_Distrito_de_Barranquilla_20250501.csv")
prueba.head()
# Out:
#     depa_nombre   muni_nombre  codigo_habilitacion  \
# 0  Barranquilla  BARRANQUILLA            800103803
# 1  Barranquilla  BARRANQUILLA            800104848
# 2  Barranquilla  BARRANQUILLA            800103637
# 3  Barranquilla  BARRANQUILLA            800105080
# 4  Barranquilla  BARRANQUILLA            800103775
#
#                                     nombre_prestador  tido_codigo  \
# 0                                    C&S GAMMA S.A.S          NaN
# 1  CIRUJANOS PEDIATRAS DE LA COSTA Y PEDIATRAS AS...          NaN
# 2                            INVERSIONES LAYNE S.A.S          NaN
# 3                         A&T SALUD INTEGRAL IPS SAS          NaN
# 4                            A.L.E. OTORRINOS S.A.S.          NaN
#
#       nits_nit                                       razon_social  \
# 0  900107671.0                                    C&S GAMMA S.A.S
# 1  901292895.0  CIRUJANOS PEDIATRAS DE LA COSTA Y PEDIATRAS AS...
# ...

# %%
prueba = prueba[prueba['clpr_nombre'] == 'Instituciones - IPS']

# %%
prueba['nombre_prestador'].unique()
# Out:
# array(['C&S GAMMA S.A.S',
#        'CIRUJANOS PEDIATRAS DE LA COSTA Y PEDIATRAS ASOCIADOS IPS SAS',
#        'INVERSIONES LAYNE S.A.S', 'A&T SALUD INTEGRAL IPS SAS',
#        'A.L.E. OTORRINOS S.A.S.', 'ADOLFO ALVAREZ SAS',
#        'ADVANCE CARDIOLOGY IPS SAS CARDIOIMAGENES',
#        'AIR LIQUIDE COLOMBIA SAS', 'AL HENRIQUEZ ORTOPEDIA S.A.S.',
#        'ALIANZA ODONTOLOGICA TIV', 'ALTA MED I.P.S. S.A.S.',
#        'AMBULANCIAS MEDICAS DEL ATLANTICO S.A.S',
#        'AMVIF - ASISTENCIA MEDICA VITAL EN FAMILIA IPS S.A.S.',
#        'ANESTEPRO SAS BARRANQUILLA', 'ANGIOLAB LTDA', 'ARPECA LTDA',
#        'ASGESST IPS SAS',
#        'ASISTENCIA DOMICILIARIA INTEGRAL EN SALUD IPS SAS',
#        'ASISTENCIA MEDICA INMEDIATA AMEDI S.A.S.',
#        'ASISTENCIA MEDICA INMEDIATA SERVICIO DE AMBULANCIA PREPAGADA S.A.',
#        'ASISTENCIA MEDICA INTEGRAL EN CASA SAS',
#        'ASOCIACIÓN DE PROFESIONALES ANESTESIÓLOGOS PERMANENTES',
# ...
